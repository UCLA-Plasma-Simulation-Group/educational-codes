# %%
import h5py

# %%
import numpy as np
import matplotlib.pyplot as plt
from analysis import *
# %matplotlib notebook

# %%
from h5_utilities import *
from analysis import *

# %%
test=read_hdf('e1.h5')

# %%
autocorrelate_2d(test.data,axes=0)

# %%
plotme(test)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(test.data[:,128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
