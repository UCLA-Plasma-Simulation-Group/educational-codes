# %%
import h5py

# %%
import numpy as np
import matplotlib.pyplot as plt
from analysis import *
# %matplotlib notebook

# %%
from h5_utilities import *
from analysis import *

# %%
test=read_hdf('e1-long.h5')

# %%
autocorrelate_2d(test.data,axes=0)

# %%
plotme(test)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(test.data[:,128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test2=read_hdf('../examples/subtraction/DIAG-large-ref/Ex/Ex-0_000100.h5')
test3=read_hdf('../examples/subtraction/DIAG/Ex/Ex-0_000100.h5')
test2.data=test2.data-test3.data

# %%
plt.figure()
plotme(test2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(test2.data[2,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
