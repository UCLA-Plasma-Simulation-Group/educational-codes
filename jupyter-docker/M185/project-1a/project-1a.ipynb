# %% [markdown]
# # Project 1a

# %% [markdown]
# # First:
#
# The following lines must always be executed before running anything else:

# %%
import osiris
# %matplotlib inline

# %% [markdown]
# # Launching Project 1a-i and 1a-ii
# (note: project-1a-i has uth = 0.01, 0.01, 0.01; project-1a-ii has uth = 0.2, 0.2, 0.2)

# %%
dirname = 'project-1a-i'
osiris.runosiris(rundir=dirname,inputfile='project-1a-i.txt')
# Out:
# runosiris completed normally...what a relief

# %%
dirname = 'project-1a-ii'
osiris.runosiris(rundir=dirname,inputfile='project-1a-ii.txt')
# Out:
# runosiris completed normally...what a relief

# %% [markdown]
# # plot_xt
# `osiris.plot(rundir, TITLE, b0_mag, plot_or, show_theory)`

# %%
# dirname = 'project-1a'
# osiris.plot_xt(rundir=dirname, TITLE='testing', b0_mag=0.7, plot_or=1, show_theory=True) 
# osiris.plot_xt(rundir=dirname, TITLE='testing', b0_mag=0.7, plot_or=2, show_theory=True) 
# osiris.plot_xt(rundir=dirname, TITLE='testing', b0_mag=0.7, plot_or=3, show_theory=True)

# %% [markdown]
# ## plot_wk: project-1a-i (low thermal velocity case)
# `osiris.plot_wk(rundir, TITLE, b0_mag, plot_or, show_theory)`

# %%
dirname = 'project-1a-i'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=3, klim=5, vth = 0.01) 
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=2, show_theory=True, wlim=3, klim=5)
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=3, show_theory=True, wlim=3, klim=5)

# %% [markdown]
# # plot_wk: project-1a-i (high thermal velocity case)

# %%
dirname = 'project-1a-ii'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=3, klim = 5, vth = 0.2) 
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=2, show_theory=True, wlim=3, klim = 5)
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=3, show_theory=True, wlim=3, klim = 5)
