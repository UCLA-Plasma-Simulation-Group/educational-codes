# %% [markdown]
# # Project 1: Plasma Waves

# %% [markdown]
# The following lines must always be executed before running anything else:

# %%
import osiris
# %matplotlib inline

# %% [markdown]
# Launch the Project 1 input decks:

# %%
# uth = 0.02
dirname = 'project-1a-i'
osiris.runosiris(rundir=dirname,inputfile='project-1a-i.txt')
# Out:
# runosiris completed normally

# %%
# uth = 0.05
dirname = 'project-1a-ii'
osiris.runosiris(rundir=dirname,inputfile='project-1a-ii.txt')
# Out:
# runosiris completed normally

# %%
# uth = 0.2
dirname = 'project-1a-iii'
osiris.runosiris(rundir=dirname,inputfile='project-1a-iii.txt')
# Out:
# runosiris completed normally

# %% [markdown]
# ## w-k plot: project-1a-i

# %% [markdown]
# * $v_{th} = 0.02$ with units of [k]=$\omega_{pe}$/c :

# %%
dirname = 'project-1a-i'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim=[0,50], 
               vth = 0.02, cmap='Rainbow') 
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=False, wlim=[0,3], klim=[0,50], 
               vth = 0.02, cmap='Rainbow')

# %% [markdown]
# -----------------------------------
# * $v_{th} = 0.02$ with units of [k]=$\omega_{pe}$/c :

# %%
dirname = 'project-1a-i'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim=[0,1], 
               vth = 0.02, cmap='Rainbow', debye=True)

# %% [markdown]
# ## w-k plot: project-1a-ii

# %% [markdown]
# * $v_{th} = 0.05$ with units of [k]=$\omega_{pe}$/c :

# %%
dirname = 'project-1a-ii'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim=[0,20], 
               vth = 0.05, cmap='Rainbow') 
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=False, wlim=[0,3], klim=[0,20], 
               vth = 0.05, cmap='Rainbow')

# %% [markdown]
# --------------
#
# * $v_{th} = 0.05$ with units of [k]=$\omega_{pe}$/c :

# %%
dirname = 'project-1a-ii'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim=[0,1], 
               vth = 0.05, cmap='Rainbow', debye=True)

# %% [markdown]
# ## w-k plot: project-1a-iii

# %% [markdown]
# * $v_{th} = 0.2$ with units of [k]=$\omega_{pe}$/c :

# %%
dirname = 'project-1a-iii'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim = [0,5], 
               cmap='Rainbow', vth = 0.2) 
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=False, wlim=[0,3], klim = [0,5], 
               cmap='Rainbow', vth = 0.2)

# %% [markdown]
# -------
# * $v_{th} = 0.05$ with units of [k]=$\lambda_D$ :

# %%
dirname = 'project-1a-iii'
osiris.plot_wk(rundir=dirname, TITLE='', b0_mag=0.0, plot_or=1, show_theory=True, wlim=[0,3], klim = [0,1], 
               cmap='Rainbow', vth = 0.2, debye=True)
