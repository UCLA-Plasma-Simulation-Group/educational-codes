# %%
import h5py

# %%
import numpy as np
import matplotlib.pyplot as plt
from analysis import *
# %matplotlib notebook

# %%
from h5_utilities import *
from analysis import *

# %%
test4=read_hdf('DIAG/Vx_x/vx_x_000000.h5')
plotme(test4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(test4.data[:,128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test=read_hdf('e1-long.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-adcb600bb081> in <module>()
# ----> 1 test=read_hdf('e1-long.h5')
#
# NameError: name 'read_hdf' is not defined

# %%
autocorrelate_2d(test.data,axes=0)

# %%
plotme(test)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(test.data[:,128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test2=read_hdf('../examples/subtraction/DIAG-ref/Ex/Ex-0_000230.h5')
test3=read_hdf('../examples/subtraction/DIAG/Ex/Ex-0_000230.h5')
test2.data=test2.data-test3.data

# %%
i = 230;
test2="test-"+"%06d"%i+".h5"
print(test2)
# Out:
# test-000230.h5

# %%
# from IPython import display
dirname1="/Users/franktsung/Documents/work/summer_school_2017/examples/subtraction/DIAG-ref/Ex/Ex-0_"
dirname2="/Users/franktsung/Documents/work/summer_school_2017//examples/subtraction/DIAG-2/Ex/Ex-0_"
# f,ax = plt.subplots()
i=300
# for i in range(2,500,2):

file2=dirname1+"%06d"%i+".h5"
file3=dirname2+"%06d"%i+".h5"
print(file2)
print(file3)
test2=read_hdf(file2)
test3=read_hdf(file3)
test2.data=test2.data-test3.data 
plotme(test2)
% ax.pcolor(test2.data)
# %ax.show()
%    display.clear_output(wait=True)
%    display.display(plt.gcf())
%    time.sleep(1.0)
    
% plotme(test2)
# Out:
# /Users/franktsung/Documents/work/summer_school_2017/examples/subtraction/DIAG-ref/Ex/Ex-0_000300.h5
# /Users/franktsung/Documents/work/summer_school_2017//examples/subtraction/DIAG-2/Ex/Ex-0_000300.h5
# <img src="data:image/png;base64,..." width="640">
# ERROR:root:Line magic function `%ax.pcolor` not found.
# ERROR:root:Line magic function `%ax.show` not found.
# ERROR:root:Line magic function `%display.clear_output` not found.
# ERROR:root:Line magic function `%display.display` not found.
# ERROR:root:Line magic function `%time.sleep` not found.
# ERROR:root:Line magic function `%plotme` not found.

# %%
plt.figure()
plt.plot(test2.data[16,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
