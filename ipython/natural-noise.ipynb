# %%
import h5py

# %%
import numpy as np
import matplotlib.pyplot as plt
from analysis import *
# %matplotlib notebook

# %%
from h5_utilities import *
from analysis import *

# %%
test4=read_hdf('/Users/uclapic/Documents/work/education/fall-2017/disp-b01/e1.h5')
plotme(test4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.semilogy(test4.data[:,128])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test=read_hdf('e1-gauss4.h5')

# %%
# k_data=np.fft.fft(test.data,axis=1)
k_data=np.fft.fft(test4.data,axis=1)
k_data_2=np.fft.fft(k_data,axis=0)
# autocorrelate_2d(k_data,axes=0)
test4.data=np.log10(np.abs(k_data_2)+1e-10)
test4.axes[1].axis_max=2.0*3.1415926/0.95
test4.axes[0].axis_max=2.0*3.1415926/0.2
# test.data=k_data
# autocorrelate_2d(test.data,axes=0)

# test_fft=np.fft.fft(test.data,axis=0)
# test_fft_2=np.fft.fft(test_fft,axis=0)
#test.data=np.log10(np.real(test_fft)+1e-10)

# %%
plt.figure()
plotme(test4)
plt.show()
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
# plt.semilogy(test.data[:,0])

plt.semilogy(test.data[:,1])


plt.semilogy(test.data[:,2])
plt.semilogy(test.data[:,3])
plt.semilogy(test.data[:,4])
plt.semilogy(test.data[:,5])

plt.semilogy(test.data[:,6])

plt.semilogy(test.data[:,7])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test2=read_hdf('../examples/subtraction/DIAG-ref/Ex/Ex-0_000230.h5')
test3=read_hdf('../examples/subtraction/DIAG/Ex/Ex-0_000230.h5')
test2.data=test2.data-test3.data

# %%
i = 230;
test2="test-"+"%06d"%i+".h5"
print(test2)
# Out:
# test-000230.h5

# %%
from IPython import display
dirname1="../examples/subtraction/DIAG-ref/Ex/Ex-0_"
dirname2="../examples/subtraction/DIAG-2/Ex/Ex-0_"
f,ax = plt.subplots()
i=300
# %for i in range(2,500,2):

file2=dirname1+"%06d"%i+".h5"
file3=dirname2+"%06d"%i+".h5"
print(file2)
print(file3)
test2=read_hdf(file2)
test3=read_hdf(file3)
test2.data=test2.data-test3.data 
plotme(test2)
% ax.pcolor(test2.data)
# %ax.show()
%    display.clear_output(wait=True)
%    display.display(plt.gcf())
%    time.sleep(1.0)
    
% plotme(test2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ERROR:root:Line magic function `%for` not found.
# ERROR:root:Line magic function `%ax.pcolor` not found.
# ERROR:root:Line magic function `%ax.show` not found.
# ERROR:root:Line magic function `%display.clear_output` not found.
# ERROR:root:Line magic function `%display.display` not found.
# ERROR:root:Line magic function `%time.sleep` not found.
# ERROR:root:Line magic function `%plotme` not found.
# ../examples/subtraction/DIAG-ref/Ex/Ex-0_000300.h5
# ../examples/subtraction/DIAG-2/Ex/Ex-0_000300.h5

# %%
plt.figure()
plt.plot(test2.data[16,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
